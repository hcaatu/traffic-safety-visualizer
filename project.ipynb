# %% [markdown]
# ### Plotting data with plotly

# %%
import geopandas as gp
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("liikenneonnettomuudet_Helsingissa.csv", sep=";")
df

gdf = ("shape.shp")
# Out:
#       LAJI   pohj_etrs     ita_etrs  VAKAV_A    VV
# 0       JK  6675786.73  25501661.91        1  2022
# 1       JK  6674533.32  25502790.94        2  2022
# 2       JK  6679536.47  25506837.81        2  2022
# 3       JK  6675297.68  25498807.13        2  2022
# 4       JK  6674924.21  25495525.13        2  2022
# ...    ...         ...          ...      ...   ...
# 53795   PP  6674696.29  25497044.46        2  2024
# 53796   PP  6675329.91  25497183.32        1  2024
# 53797   PP  6675746.02  25494119.16        1  2024
# 53798   PP  6678387.52  25494869.15        1  2024
# 53799   PP  6684306.71  25502593.86        2  2024
#
# [53800 rows x 5 columns]
